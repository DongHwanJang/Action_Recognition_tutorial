# %%
import torch
import numpy as np
from C3D import C3D
import time
import data_processing_sol as data_processing
import os
import os.path
from os.path import join
import pickle
from torch.utils.data import DataLoader
from torch.nn import functional as F

#Run the code using selected GPU
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "1"
TRAIN_LOG_DIR = os.path.join('Log/train/', time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(time.time())))
TRAIN_CHECK_POINT = 'check_point/'

#Experiment, Optimization options
DATA_SPLIT_PATH = 'data_split.pkl'
BATCH_SIZE = 10
NUM_CLASSES = 11
CROP_SIZE = 112
CHANNEL_NUM = 3
CLIP_LENGTH = 16
EPOCH_NUM = 50
LEARNING_RATE = 1e-4

# %% [markdown]
# ## 1) Load UCF11(UCF YouTube Action) Dataset Path

# %%
DATA_SPLIT_PATH = 'data_split.pkl'
ucf11_dataset = pickle.load(open(DATA_SPLIT_PATH,'rb'))
train_set = ucf11_dataset['train']
test_set = ucf11_dataset['test']

# %% [markdown]
# ## 2) Set Dataset and Dataloader

# %%
train_video_dataset = data_processing.UCF11Dataset(train_set, NUM_CLASSES)
test_video_dataset = data_processing.UCF11Dataset(test_set, NUM_CLASSES)

train_video_dataloader = DataLoader(train_video_dataset, batch_size = BATCH_SIZE, shuffle=True)
test_video_dataloader = DataLoader(test_video_dataset, batch_size = BATCH_SIZE, shuffle=True)

# %% [markdown]
# ## 3) Set Network and Optimizer

# %%
net = C3D(num_classes=NUM_CLASSES)
net = net.cuda()

optimizer = torch.optim.Adam(net.parameters(), lr=LEARNING_RATE)

# %% [markdown]
# ### - Train and Test C3D

# %%
for epoch in range(EPOCH_NUM):
    # train
    correct_epoch = 0
    loss_epoch = 0
    net.train()
    
    for i, batch in enumerate(train_video_dataloader):        
        batch_clips = batch['clips']
        batch_labels = batch['labels']
        batch_clips = batch_clips.cuda()
        batch_labels = batch_labels.cuda()
        
        logits = net(batch_clips)                

        loss = F.cross_entropy(logits, batch_labels)
        correct = (torch.argmax(logits, 1) == batch_labels).sum()
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        loss_epoch += loss
        correct_epoch += correct
        
        if i % 10 == 0:
            print('Epoch %d, Batch %d: Loss is %.5f; Accuracy is %.5f'%(epoch+1, i, loss, correct/batch_clips.shape[0]))
            
    print('Epoch %d: Average loss is: %.5f; Average accuracy is: %.5f'%(epoch+1, loss_epoch / len(train_video_dataloader),
                                                                                correct_epoch / len(train_video_dataset)))
                
    # test
    correct_epoch = 0
    loss_epoch = 0
    net.eval()
    
    with torch.no_grad():
        for i, batch in enumerate(test_video_dataloader):
            batch_clips = batch['clips']
            batch_labels = batch['labels']
            batch_clips = batch_clips.cuda()
            batch_labels = batch_labels.cuda()

            logits = net(batch_clips)

            loss = F.cross_entropy(logits, batch_labels)
            correct = (torch.argmax(logits, 1) == batch_labels).sum()    

            loss_epoch += loss
            correct_epoch += correct
        
    print('Test loss is %.5f; Accuracy is %.5f'%(loss_epoch / len(test_video_dataloader),
                                                                                correct_epoch / len(test_video_dataset)))
# Out:
# Epoch 12, Batch 80: Loss is 0.60950; Accuracy is 0.80000
# Epoch 12, Batch 90: Loss is 0.31268; Accuracy is 0.90000
# Epoch 12, Batch 100: Loss is 0.52686; Accuracy is 0.80000
# Epoch 12, Batch 110: Loss is 0.46270; Accuracy is 0.90000
# Epoch 12: Average loss is: 0.38326; Average accuracy is: 0.89239
# Test loss is 3.07628; Accuracy is 0.46875
# Epoch 13, Batch 0: Loss is 0.29668; Accuracy is 0.80000
# Epoch 13, Batch 10: Loss is 0.53892; Accuracy is 0.80000
# Epoch 13, Batch 20: Loss is 0.37156; Accuracy is 0.90000
# Epoch 13, Batch 30: Loss is 0.34421; Accuracy is 0.80000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-cd9a91cab4a1> in <module>
#       5     net.train()
#       6
# ----> 7     for i, batch in enumerate(train_video_dataloader):
#       8 #         import pdb; pdb.set_trace()
#       9
#
# ~/anaconda3/envs/action_tutorial2/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     519             if self._sampler_iter is None:
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#     523             if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/anaconda3/envs/action_tutorial2/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     559     def _next_data(self):
#     560         index = self._next_index()  # may raise StopIteration
# --> 561         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     562         if self._pin_memory:
#     563             data = _utils.pin_memory.pin_memory(data)
#
# ~/anaconda3/envs/action_tutorial2/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/anaconda3/envs/action_tutorial2/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/PycharmProjects/Action_Recognition_tutorial/2_C3D_nonlocal/data_processing_sol.py in __getitem__(self, i)
#      90         dirname = line[0]
#      91         label = int(self.data_list[dirname])
# ---> 92         clips = convert_images_to_clip(dirname, CLIP_LENGTH, self.crop_size, self.channel_num)
#      93
#      94         clips = np.transpose(np.array(clips).astype(np.float32), (3, 0, 1, 2))
#
# ~/PycharmProjects/Action_Recognition_tutorial/2_C3D_nonlocal/data_processing_sol.py in convert_images_to_clip(filename, clip_length, crop_size, channel_num)
#      72     if len(clip) == 0:
#      73         print(filename)
# ---> 74     clip = frame_process(clip, clip_length, crop_size, channel_num)
#      75     return clip#shape[clip_length, crop_size, crop_size, channel_num]
#      76
#
# ~/PycharmProjects/Action_Recognition_tutorial/2_C3D_nonlocal/data_processing_sol.py in frame_process(clip, clip_length, crop_size, channel_num)
#      33     #Crop every frame into shape[crop_size, crop_size, channel_num]
#      34     for i in range(frames_num):
# ---> 35         img = Image.fromarray(clip[i].astype(np.uint8))
#      36         if img.width > img.height:
#      37             scale = float(crop_size) / float(img.height)
#
# ~/anaconda3/envs/action_tutorial2/lib/python3.7/site-packages/PIL/Image.py in fromarray(obj, mode)
#    2847             obj = obj.tostring()
#    2848
# -> 2849     return frombuffer(mode, size, obj, "raw", rawmode, 0, 1)
#    2850
#    2851
#
# ~/anaconda3/envs/action_tutorial2/lib/python3.7/site-packages/PIL/Image.py in frombuffer(mode, size, data, decoder_name, *args)
#    2787             return im
#    2788
# -> 2789     return frombytes(mode, size, data, decoder_name, args)
#    2790
#    2791
#
# ~/anaconda3/envs/action_tutorial2/lib/python3.7/site-packages/PIL/Image.py in frombytes(mode, size, data, decoder_name, *args)
#    2732         args = mode
#    2733
# -> 2734     im = new(mode, size)
#    2735     im.frombytes(data, decoder_name, args)
#    2736     return im
#
# ~/anaconda3/envs/action_tutorial2/lib/python3.7/site-packages/PIL/Image.py in new(mode, size, color)
#    2696         im.palette = ImagePalette.ImagePalette()
#    2697         color = im.palette.getcolor(color)
# -> 2698     return im._new(core.fill(mode, size, color))
#    2699
#    2700
#
# KeyboardInterrupt:

# %% [markdown]
# ###
